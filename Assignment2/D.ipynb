# %% [markdown]
# Name: Harshith Akkapelli
#
# Task-4: Associate Rule Mining
#
# Dataset Link: [Groceries dataset ](https://www.kaggle.com/datasets/heeraldedhia/groceries-dataset)

# %%
# !pip install pycaret==2.1.2
from pycaret.arules import *
# Out:
# Collecting pycaret==2.1.2
#   Using cached pycaret-2.1.2-py3-none-any.whl (252 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.23.5)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (0.12.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (3.7.1)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (7.34.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.3.2)
# Requirement already satisfied: scikit-learn>=0.23 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.2.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (7.7.1)
# Requirement already satisfied: yellowbrick>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.5)
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.7.6)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (4.0.0)
# Requirement already satisfied: plotly>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (5.15.0)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.9.2)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (0.17.1)
# Requirement already satisfied: cufflinks>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (0.17.3)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (0.5.3)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (3.4.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (4.3.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (3.6.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (3.8.1)
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (0.22.0)
# Requirement already satisfied: pyod in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.1.0)
# Requirement already satisfied: catboost>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.2.1)
# Requirement already satisfied: pandas-profiling>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (3.6.6)
# Requirement already satisfied: kmodes>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (0.12.2)
# Requirement already satisfied: datefinder>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (0.7.3)
# Requirement already satisfied: mlflow in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (1.30.1)
# Requirement already satisfied: imbalanced-learn>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from pycaret==2.1.2) (0.10.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost>=0.23.2->pycaret==2.1.2) (0.20.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost>=0.23.2->pycaret==2.1.2) (1.10.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost>=0.23.2->pycaret==2.1.2) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from cufflinks>=0.17.0->pycaret==2.1.2) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /usr/local/lib/python3.10/dist-packages (from cufflinks>=0.17.0->pycaret==2.1.2) (67.7.2)
# Requirement already satisfied: regex>=2017.02.08 in /usr/local/lib/python3.10/dist-packages (from datefinder>=0.7.0->pycaret==2.1.2) (2023.6.3)
# Requirement already satisfied: python-dateutil>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from datefinder>=0.7.0->pycaret==2.1.2) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from datefinder>=0.7.0->pycaret==2.1.2) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn>=0.6.2->pycaret==2.1.2) (3.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (0.19.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->pycaret==2.1.2) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pycaret==2.1.2) (6.25.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pycaret==2.1.2) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pycaret==2.1.2) (3.6.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pycaret==2.1.2) (3.0.8)
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.10/dist-packages (from pandas-profiling>=2.8.0->pycaret==2.1.2) (4.5.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.4.1->pycaret==2.1.2) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.4.1->pycaret==2.1.2) (21.3)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from yellowbrick>=1.0.1->pycaret==2.1.2) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pycaret==2.1.2) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pycaret==2.1.2) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pycaret==2.1.2) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pycaret==2.1.2) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pycaret==2.1.2) (3.1.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->pycaret==2.1.2) (6.3.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (8.1.7)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (2.2.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (0.17.7)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (3.1.35)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (3.20.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (2.31.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (5.2.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (0.4.4)
# Requirement already satisfied: alembic<2 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (1.12.0)
# Requirement already satisfied: docker<7,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (6.1.3)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (2.2.3)
# Requirement already satisfied: prometheus-flask-exporter<1 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (0.22.4)
# Requirement already satisfied: querystring-parser<2 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (1.2.4)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (1.4.49)
# Requirement already satisfied: gunicorn<21 in /usr/local/lib/python3.10/dist-packages (from mlflow->pycaret==2.1.2) (20.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->pycaret==2.1.2) (4.66.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis->pycaret==2.1.2) (3.1.2)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis->pycaret==2.1.2) (2.8.5)
# Requirement already satisfied: funcy in /usr/local/lib/python3.10/dist-packages (from pyLDAvis->pycaret==2.1.2) (2.0)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.10/dist-packages (from pyod->pycaret==2.1.2) (0.56.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (0.10.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (1.10.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->pycaret==2.1.2) (3.3.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn->pycaret==2.1.2) (0.5.10)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic<2->mlflow->pycaret==2.1.2) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic<2->mlflow->pycaret==2.1.2) (4.5.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/lib/python3/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret==2.1.2) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret==2.1.2) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret==2.1.2) (0.9.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret==2.1.2) (1.26.16)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker<7,>=4.0.0->mlflow->pycaret==2.1.2) (1.6.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<3->mlflow->pycaret==2.1.2) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3->mlflow->pycaret==2.1.2) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython<4,>=2.1.0->mlflow->pycaret==2.1.2) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow->pycaret==2.1.2) (3.16.2)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (5.3.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (1.5.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (23.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->pycaret==2.1.2) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->pyLDAvis->pycaret==2.1.2) (2.1.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51->pyod->pycaret==2.1.2) (0.39.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->pycaret==2.1.2) (0.7.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from prometheus-flask-exporter<1->mlflow->pycaret==2.1.2) (0.17.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret==2.1.2) (0.2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow->pycaret==2.1.2) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow->pycaret==2.1.2) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow->pycaret==2.1.2) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<2,>=1.4.0->mlflow->pycaret==2.1.2) (2.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->pycaret==2.1.2) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->pycaret==2.1.2) (0.1.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (6.5.5)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (0.7.5)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (0.12.3)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (1.9.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (0.14.0)
# Requirement already satisfied: typeguard<3,>=2.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (4.3.1)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (1.8.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (1.4.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (0.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->pycaret==2.1.2) (5.0.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->pycaret==2.1.2) (3.10.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (1.0.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.1.2) (0.5.3)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (4.19.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.10.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (3.7.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.1.2) (2.21)
# Installing collected packages: pycaret
#   Attempting uninstall: pycaret
#     Found existing installation: pycaret 2.2
#     Uninstalling pycaret-2.2:
#       Successfully uninstalled pycaret-2.2
# Successfully installed pycaret-2.1.2

# %%
"""Mount Google Drive to access your data"""
from google.colab import drive #Import library
drive.mount('/content/drive') #Mount it
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""IMPORT DATA AND HANDLE MISSING VALUES"""
import pandas as pd #Import Library

"""Function to load and remove na valued rows"""
def importData(url):
  print("Started Reading Data")
  getData = pd.read_csv(url)
  print("Completed Reading Data")
  print(getData.head())
  print("Removing na values")
  getData = getData.dropna()
  print("Removed rows with na values")
  return getData

url = '/content/drive/MyDrive/4.csv'
inputData = importData(url) #Call the Function
# Out:
# Started Reading Data
# Completed Reading Data
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk
# Removing na values
# Removed rows with na values

# %%
from pycaret.arules import *
"""Function to set up the environment"""
def doSetUpOfPycaret(inputData,tranId,Id):
  print("Setting up the environment")
  s = setup(inputData,tranId, item_id=Id)
  print("Environment is set up")
  return s

s = doSetUpOfPycaret(inputData,"Member_number","itemDescription")#Call the Function
# Out:
# Setting up the environment
# <style type="text/css">
# </style>
# <table id="T_fb216" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_fb216_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fb216_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fb216_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_fb216_row0_col1" class="data row0 col1" >8233</td>
#     </tr>
#     <tr>
#       <td id="T_fb216_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_fb216_row1_col1" class="data row1 col1" >3898</td>
#     </tr>
#     <tr>
#       <td id="T_fb216_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_fb216_row2_col1" class="data row2 col1" >167</td>
#     </tr>
#     <tr>
#       <td id="T_fb216_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_fb216_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# </table>
# Environment is set up

# %%
"""Function to Train and Evaluate the models"""
def trainAndBenchmarkModels():
  #Training Phase
  print("Starting Training of models")
  finalModel = create_model()
  print("Completed Training of models")

  #Return model
  return finalModel
finalModel = trainAndBenchmarkModels()
# Out:
# Starting Training of models
# Completed Training of models

# %%
finalModel
# Out:
#                            antecedents         consequents  \
# 0    (bottled water, other vegetables)        (whole milk)
# 1           (yogurt, other vegetables)        (whole milk)
# 2                 (rolls/buns, yogurt)        (whole milk)
# 3       (rolls/buns, other vegetables)        (whole milk)
# 4                       (soda, yogurt)        (whole milk)
# 5             (soda, other vegetables)        (whole milk)
# 6   (tropical fruit, other vegetables)        (whole milk)
# 7                   (soda, rolls/buns)        (whole milk)
# 8                      (shopping bags)        (whole milk)
# 9          (sausage, other vegetables)        (whole milk)
# 10                      (bottled beer)        (whole milk)
# 11                 (frozen vegetables)        (whole milk)
# 12                              (beef)        (whole milk)
# 13                            (yogurt)        (whole milk)
# 14                       (canned beer)        (whole milk)
# 15                     (domestic eggs)        (whole milk)
# 16                              (curd)        (whole milk)
# 17                     (bottled water)        (whole milk)
# 18                            (butter)        (whole milk)
# 19                           (sausage)        (whole milk)
# 20                        (newspapers)        (whole milk)
# 21                (whipped/sour cream)        (whole milk)
# 22                       (brown bread)        (whole milk)
# 23                            (pastry)        (whole milk)
# 24                        (rolls/buns)        (whole milk)
# 25                         (pip fruit)        (whole milk)
# 26                         (margarine)        (whole milk)
# 27                  (other vegetables)        (whole milk)
# 28                              (pork)        (whole milk)
# 29         (whole milk, bottled water)  (other vegetables)
#
#     antecedent support  consequent support  support  confidence    lift  \
# 0               0.0939              0.4582   0.0562      0.5984  1.3059
# 1               0.1203              0.4582   0.0718      0.5970  1.3030
# 2               0.1113              0.4582   0.0659      0.5922  1.2924
# 3               0.1467              0.4582   0.0821      0.5594  1.2210
# 4               0.0975              0.4582   0.0544      0.5579  1.2176
# 5               0.1242              0.4582   0.0693      0.5579  1.2175
# 6               0.0913              0.4582   0.0505      0.5534  1.2077
# 7               0.1198              0.4582   0.0652      0.5439  1.1871
# 8               0.1683              0.4582   0.0913      0.5427  1.1844
# 9               0.0929              0.4582   0.0503      0.5414  1.1817
# 10              0.1588              0.4582   0.0854      0.5380  1.1741
# 11              0.1026              0.4582   0.0552      0.5375  1.1731
# 12              0.1195              0.4582   0.0641      0.5365  1.1709
# 13              0.2830              0.4582   0.1506      0.5322  1.1615
# 14              0.1652              0.4582   0.0872      0.5280  1.1523
# 15              0.1331              0.4582   0.0703      0.5279  1.1522
# 16              0.1208              0.4582   0.0636      0.5265  1.1492
# 17              0.2137              0.4582   0.1124      0.5258  1.1476
# 18              0.1265              0.4582   0.0662      0.5233  1.1422
# 19              0.2060              0.4582   0.1070      0.5193  1.1334
# 20              0.1398              0.4582   0.0723      0.5174  1.1293
# 21              0.1547              0.4582   0.0798      0.5158  1.1257
# 22              0.1360              0.4582   0.0698      0.5132  1.1201
# 23              0.1775              0.4582   0.0911      0.5130  1.1197
# 24              0.3497              0.4582   0.1786      0.5106  1.1145
# 25              0.1706              0.4582   0.0870      0.5098  1.1126
# 26              0.1170              0.4582   0.0595      0.5088  1.1104
# 27              0.3766              0.4582   0.1914      0.5082  1.1091
# 28              0.1324              0.4582   0.0670      0.5058  1.1040
# 29              0.1124              0.3766   0.0562      0.5000  1.3277
#
#     leverage  conviction  zhangs_metric
# 0     0.0132      1.3490         0.2585
# 1     0.0167      1.3445         0.2643
# 2     0.0149      1.3285         0.2546
# 3     0.0149      1.2298         0.2121
# 4     0.0097      1.2255         0.1980
# 5     0.0124      1.2254         0.2040
# 6     0.0087      1.2131         0.1893
# 7     0.0103      1.1879         0.1790
# 8     0.0142      1.1848         0.1872
# 9     0.0077      1.1816         0.1695
# 10    0.0127      1.1727         0.1763
# 11    0.0081      1.1715         0.1644
# 12    0.0094      1.1689         0.1658
# 13    0.0209      1.1582         0.1939
# 14    0.0115      1.1478         0.1583
# 15    0.0093      1.1478         0.1524
# 16    0.0083      1.1444         0.1477
# 17    0.0145      1.1426         0.1636
# 18    0.0082      1.1367         0.1425
# 19    0.0126      1.1271         0.1482
# 20    0.0083      1.1228         0.1331
# 21    0.0089      1.1189         0.1321
# 22    0.0075      1.1130         0.1241
# 23    0.0097      1.1126         0.1299
# 24    0.0183      1.1072         0.1580
# 25    0.0088      1.1052         0.1220
# 26    0.0059      1.1030         0.1126
# 27    0.0188      1.1016         0.1578
# 28    0.0063      1.0964         0.1085
# 29    0.0139      1.2468         0.2780
